# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
# <center><b><h1>Preet Parmar(211)</b></center>
# <center><b><h1>Lab - 2</b></center>
# <pre>

# %% [markdown]
# # Exploratory Data Analysis (EDA) Of Loan Default detection

# %%
import pandas as pd
df = pd.read_csv("Loan_default.csv")
df
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %% [markdown]
# # 1. Dataset Overview
#
# Dataset Overview is the first step in **Exploratory Data Analysis (EDA)**. It provides a quick understanding of the dataset's structure, size, and features before performing further analysis.
#
# ### Questions
#
# 1. What is the shape of the dataset?
# 2. How many rows are there?
# 3. How many columns are there?
# 4. What is the data type of each column?
# 5. Print the name of all the columns.

# %%
df.shape
# Out:
# (255347, 18)

# %%
df.shape[0]
# Out:
# 255347

# %%
df.shape[1]
# Out:
# 18

# %%
df.dtypes
# Out:
# LoanID             object
# Age                 int64
# Income              int64
# LoanAmount          int64
# CreditScore         int64
# MonthsEmployed      int64
# NumCreditLines      int64
# InterestRate      float64
# LoanTerm            int64
# DTIRatio          float64
# Education          object
# EmploymentType     object
# MaritalStatus      object
# HasMortgage        object
# HasDependents      object
# LoanPurpose        object
# HasCoSigner        object
# Default             int64
# dtype: object

# %%
df.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'],
#       dtype='object')

# %% [markdown]
# # 2. DataFrame Summary
#
# A **DataFrame Summary** provides a statistical overview of the dataset. It helps you quickly understand the distribution, central tendency, spread, and count of values in numerical columns. You can summarize the entire DataFrame or focus on specific columns based on your analysis needs.
#
# ### Questions
#
# 1. Summarize the entire DataFrame.
# 2. Summarize all the columns.
# 3. Summarize any one particular column.
# 4. Summarize any two or more columns at once.

# %%
df.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
df.describe(include="all")
# Out:
#             LoanID            Age         Income     LoanAmount  \
# count       255347  255347.000000  255347.000000  255347.000000
# unique      255347            NaN            NaN            NaN
# top     I38PQUQS96            NaN            NaN            NaN
# freq             1            NaN            NaN            NaN
# mean           NaN      43.498306   82499.304597  127578.865512
# std            NaN      14.990258   38963.013729   70840.706142
# min            NaN      18.000000   15000.000000    5000.000000
# 25%            NaN      31.000000   48825.500000   66156.000000
# 50%            NaN      43.000000   82466.000000  127556.000000
# 75%            NaN      56.000000  116219.000000  188985.000000
# max            NaN      69.000000  149999.000000  249999.000000
#
#           CreditScore  MonthsEmployed  NumCreditLines   InterestRate  \
# count   255347.000000   255347.000000   255347.000000  255347.000000
# ...

# %%
df["LoanAmount"].describe()
# Out:
# count    255347.000000
# mean     127578.865512
# std       70840.706142
# min        5000.000000
# 25%       66156.000000
# 50%      127556.000000
# 75%      188985.000000
# max      249999.000000
# Name: LoanAmount, dtype: float64

# %%
df[["LoanAmount" , "CreditScore" , "Default"]].describe(include="all")
# Out:
#           LoanAmount    CreditScore        Default
# count  255347.000000  255347.000000  255347.000000
# mean   127578.865512     574.264346       0.116128
# std     70840.706142     158.903867       0.320379
# min      5000.000000     300.000000       0.000000
# 25%     66156.000000     437.000000       0.000000
# 50%    127556.000000     574.000000       0.000000
# 75%    188985.000000     712.000000       0.000000
# max    249999.000000     849.000000       1.000000

# %% [markdown]
# # 3. Selecting Columns
#
# Selecting columns allows you to extract one or more specific columns from a DataFrame for analysis. This helps you focus only on the relevant data instead of working with the entire dataset.
#
# ### Questions
#
# 1. Select and display the **`LoanAmount`** column.
# 2. Select and display the **`Education`**, **`InterestRate`**, and **`Default`** columns.
# 3. Select the **`Income`**, **`LoanAmount`**, and **`CreditScore`** columns, and display only the **last 10 records**.
# 4. Store the **`InterestRate`** column as a Pandas **Series** named **`IR`**, and print its data type.

# %%
df["LoanAmount"]
# Out:
# 0          50587
# 1         124440
# 2         129188
# 3          44799
# 4           9139
#            ...
# 255342    210682
# 255343    189899
# 255344    208294
# 255345     60575
# 255346     18481
# Name: LoanAmount, Length: 255347, dtype: int64

# %%
df[["Education" , "InterestRate" , "Default"]]
# Out:
#           Education  InterestRate  Default
# 0        Bachelor's         15.23        0
# 1          Master's          4.81        0
# 2          Master's         21.17        1
# 3       High School          7.07        0
# 4        Bachelor's          6.51        0
# ...             ...           ...      ...
# 255342   Bachelor's         14.11        0
# 255343  High School         11.55        1
# 255344  High School          5.29        0
# 255345  High School         20.90        0
# 255346   Bachelor's          6.73        0
#
# [255347 rows x 3 columns]

# %%
df[["Income" , "LoanAmount" , "CreditScore"]].tail(10)
# Out:
#         Income  LoanAmount  CreditScore
# 255337   73743      140354          300
# 255338   21711      168231          352
# 255339   69492      122962          348
# 255340   61809      119238          444
# 255341  129890      116119          701
# 255342   37979      210682          541
# 255343   51953      189899          511
# 255344   84820      208294          597
# 255345   85109       60575          809
# 255346   22418       18481          636

# %% [markdown]
# # 4. Filtering Data
#
# Filtering allows you to retrieve only the rows that satisfy one or more conditions. It helps you focus on specific records for analysis without modifying the original dataset.
#
# ### Questions
#
# 1. Display all records where the **`CreditScore`** is less than **400**.
#
# 2. Display all records where the **`LoanAmount`** is greater than **200000**.
#
# 3. Display all records where the **`EmploymentType`** is **'Unemployed'**.
#
# 4. Display all records where the **`DTIRatio`** is greater than **0.50** and the **`Default`** value is **1**.
#
# 5. Identify the **high-risk borrower segment** by filtering records that satisfy all of the following conditions:
#
#    - `CreditScore` less than **650**
#    - `Income` less than **50000**
#    - `DTIRatio` greater than **0.40**
#    - `InterestRate` greater than **12**
#    - `MonthsEmployed` less than **24**

# %%
df[df["CreditScore"] < 400]
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 11      Y8UETC3LSG   28  149227      139759          375              56
# 13      GX5YQOGROM   53  117550       95744          395             112
# 16      ZDDRGVTEXS   20  119704       25697          313              49
# 18      O1IKKLC69B   19   40718       78515          319             119
# 19      F7487UU2BF   41  123419      161146          376              65
# ...            ...  ...     ...         ...          ...             ...
# 255317  UA896W9ZCS   46   49616       31272          372              31
# 255324  Q8OXUYF0TI   50   34641      108855          347              17
# 255337  DSL4O0KAWD   64   73743      140354          300               0
# 255338  6V8S5IUS63   68   21711      168231          352              78
# 255339  O6SWO6CBGB   51   69492      122962          348              66
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
df[df["LoanAmount"] > 200000]
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 9       CM9L1GTT2P   40  132784      228510          480             114
# 15      O5DM5MPPNA   41   74064      230883          432              31
# 31      P3EX8G0AYT   44  100284      225403          551              31
# 36      8NTWNU4HTY   64  102463      218433          506              24
# 42      KAC7P2RE1X   68  111716      215851          747              99
# ...            ...  ...     ...         ...          ...             ...
# 255326  FYGOB527WK   48   44894      202276          473              10
# 255328  P3UCIPJVTB   50   21890      226684          839              62
# 255335  OQ99DN6JL4   41  124446      249800          650              60
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255344  XQK1UUUNGP   56   84820      208294          597              70
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
df[df["EmploymentType"] == "Unemployed"]
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 4       EY08JDHTZP   60   20437        9139          633               8
# 5       A9S62RQ7US   25   90298       90448          720              18
# 6       H8GXPAOS71   38  111188      177025          429              80
# 10      IA35XVH6ZO   28  140466      163781          652              94
# ...            ...  ...     ...         ...          ...             ...
# 255326  FYGOB527WK   48   44894      202276          473              10
# 255329  QXBHNXNA9X   34   53658      187245          847              35
# 255333  BM4B25R7EI   22   45575       43355          545              99
# 255335  OQ99DN6JL4   41  124446      249800          650              60
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
df[(df["DTIRatio"] == 0.50) & (df["Default"] == 1)]
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 280     UZUW6Q652D   45  146321      148088          304             106
# 651     62UIBIHXWI   22  134935      132709          344              14
# 1298    RMIDP4M6KH   18  137855       65904          683              17
# 1998    8R83M3QJDF   24   99944       45213          655              96
# 2877    5FB5M1D599   46   45718       61799          431              17
# ...            ...  ...     ...         ...          ...             ...
# 251670  6CA62BXMAE   24   32775       54145          594             100
# 253392  LH016N48MW   52   67660       57354          704              33
# 254281  HO7ZNL86DX   54   67281      135981          726              38
# 254493  0QN6SK79QA   18  100512        7875          756              25
# 255202  Y4JV3HO365   50  147037       99510          743              48
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
df[(df["CreditScore"] < 500) & (df["Income"] < 50000) & (df["DTIRatio"] > 0.40) & (df["InterestRate"] > 12) & (df["MonthsEmployed"] < 24)]
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 55      QHPWTGMTU8   37   37173      234059          455              20
# 83      QTEXRYSK63   32   46238      134941          421               1
# 277     QNWQWY4A8L   57   23764       78444          315              21
# 394     RBGYQW2ZUP   50   33014      118574          344               2
# 402     NR7X7N3A1C   63   38176       52978          370               2
# ...            ...  ...     ...         ...          ...             ...
# 253598  B3OYYVTM7G   55   17385      155324          400              17
# 253891  TFABKCW3Y4   61   42189      138135          378               5
# 253968  4ZG3RLB1V5   57   32599       91929          373               2
# 254251  77FCMD364I   21   26646       55849          478              13
# 254940  KN7YOLJMVJ   33   20208      168159          333              17
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %% [markdown]
# # 5. Sorting Data
#
# Sorting arranges the rows of a DataFrame in ascending or descending order based on one or more columns. It helps identify the highest, lowest, or ordered values in the dataset.
#
# ### Questions
#
# 1. Sort the dataset by **`LoanAmount`** in **descending order** and display the top **10** borrowers with the highest loan amounts.
#
# 2. Sort the dataset by **`CreditScore`** in **ascending order** and display the first **15** records.
#
# 3. Sort the dataset by **`InterestRate`** in **descending order** and display the top **20** borrowers paying the highest interest rates.
#
# 4. Sort the dataset first by **`Default`** (descending) and then by **`CreditScore`** (ascending). Display the first **10** records.
#
# 5. Identify the **highest-risk borrowers** by combining **filtering, selection, and sorting**:
#
#    - Filter records where:
#      - `CreditScore` < 650
#      - `DTIRatio` > 0.40
#      - `Default` = 1
#
#    - Select only the following columns:
#      - `LoanID`
#      - `CreditScore`
#      - `Income`
#      - `LoanAmount`
#      - `InterestRate`
#      - `DTIRatio`
#      - `Default`
#
#    - Sort the resulting data by:
#      1. `InterestRate` (descending)
#      2. `LoanAmount` (descending)
#
#    - Display the top **15** records and write **3 observations** about the borrowers with the highest risk profile.

# %%
df.sort_values("LoanAmount" , ascending=False).head(10)
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 20256   BZ6O5YSSA8   37  114264      249999          598             106
# 232552  TGYZ4AXW7H   52  140430      249998          484              80
# 206804  VIS6H9YBJM   44   76674      249997          304              87
# 239262  7OV9HHSV62   26  137747      249996          451              47
# 135381  RXGEJP7QPL   65   23329      249993          684               4
# 171401  INBGJEMBW3   54  145587      249993          332              59
# 32834   T81D0AKB24   64   66167      249992          794              33
# 182365  TE1MRP009B   37  136184      249990          675              86
# 234220  PVLUX5GH5X   18   20288      249989          302              92
# 204609  OFQMCX2Z37   39   40994      249988          827              95
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 20256                3          8.47        36      0.71  High School
# ...

# %%
df.sort_values("CreditScore" , ascending=True).head(15)
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 159951  NLJLI00NIJ   38  117688       19952          300              27
# 209976  JBL7TU9ODS   47   31962       66533          300             101
# 125243  JHHEW0HYC7   24   53586       79798          300              86
# 200003  U5MJ71Z7U7   35   33830       99614          300               5
# 113980  2Y340RE0Y2   27   48728      221478          300              47
# 104936  4L7NX50RVS   22  127513      246432          300              31
# 178926  BO9EVOX5IX   36   61352      149465          300              35
# 105819  O5SUBTA9I8   40  126490      234038          300              99
# 218144  2LOZOBVKR0   50   39700      108847          300             118
# 138645  634DT1FZBY   66   55170      205584          300              68
# 125177  U8V2Q7REI0   53   49528      146916          300             119
# 75319   JJFUYCZYR3   61  101179       36599          300             112
# ...

# %%
df.sort_values("InterestRate" , ascending=False).head(20)
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 139618  IZR3HH9EGO   60  115446       65370          335              51
# 15166   BHYZBBTTVN   68   83030       92174          398              95
# 219887  QFWRQD2FJV   18   70063      125793          639              39
# 53301   BDUC5NF515   55  110674      137638          810              25
# 76511   DPW2MKCOYH   34   74245       87235          803              39
# 88852   I5RHWFFR30   49  100763       79163          821              75
# 177944  JXEFL5UJ22   68   47375       38484          323              30
# 81539   YRYS6J1ULV   63  108158      116889          352              38
# 160486  ZDBFTPNGS7   64  136615       12418          666              69
# 187625  O8M2TK1N4J   69   67995      140313          527               0
# 117264  SEPV2SFJ5E   30   82869      205910          702               7
# 26568   D0O9MHEOQI   60   38367       67952          805              70
# ...

# %%
df.sort_values(["Default" , "CreditScore"] , ascending=[False , True]).head(10)
# Out:
#            LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 2561   CIS1M4Q4DN   20  118332      211028          300               6
# 2576   X507HBUSXL   56   25442      118892          300               7
# 3547   SWEO9RN44J   44   76912      132882          300              80
# 5597   Q057CQ65UF   60   83205      245621          300              15
# 8304   3SBMA7KAYV   18   74378       27637          300              37
# 20972  J0IY4N83S7   64   95649       78635          300              97
# 21449  IEXC94MQKJ   57  100322      151862          300             114
# 27060  DGIF4BGB8R   35   18803       98771          300              23
# 33538  9ZE53DHWDA   59   96499      164969          300              61
# 36120  26ZT9WMCZI   50   98305      240142          300              58
#
#        NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 2561                3         15.46        36      0.74  High School
# ...

# %%
xyz = df[(df["CreditScore"] < 650) & (df["DTIRatio"] > 0.40) & (df["Default"] == 1)]

xyz[["LoanID" , "CreditScore" , "Income" , "LoanAmount" , "InterestRate" , "DTIRatio" , "Default"]].sort_values(["InterestRate" , "LoanAmount"] , ascending=[False , False]).head(15)
# Out:
#             LoanID  CreditScore  Income  LoanAmount  InterestRate  DTIRatio  \
# 79994   2KEK7ACV34          323  124334      197142         25.00      0.56
# 46593   7EN8YA37EO          404   28744      179265         25.00      0.51
# 29291   SSMTMEB9V9          359   28667      170341         25.00      0.86
# 219887  QFWRQD2FJV          639   70063      125793         25.00      0.44
# 79519   CLSZWLGGGN          360   83904       64580         25.00      0.65
# 210369  KDJCKP7CA2          636  142049      246571         24.99      0.77
# 68807   N2X49FKIHC          623   15361      244665         24.99      0.65
# 40779   DKY1MNQ84A          440   91796      233570         24.99      0.86
# 154439  EN5UKPIQC4          489   16534      221024         24.99      0.53
# 23674   CTDHC8Z5PX          535   35383      215920         24.99      0.52
# 127129  60DSFI44OU          310   64947      191686         24.99      0.60
# ...

# %% [markdown]
# # 6. Value Counts
#
# Value Counts helps determine the frequency of unique values in a column. It is useful for understanding class distribution, identifying dominant categories, and detecting imbalance in the dataset.
#
# ### Questions
#
# 1. Count how many borrowers belong to each **`EmploymentType`**.
#
# 2. Count how many loans were taken for each **`LoanPurpose`**.
#
# 3. Count the number of borrowers in each **`Education`** category and display the results in descending order.

# %%
df["EmploymentType"].value_counts()
# Out:
# EmploymentType
# Part-time        64161
# Unemployed       63824
# Self-employed    63706
# Full-time        63656
# Name: count, dtype: int64

# %%
df["LoanPurpose"].value_counts()
# Out:
# LoanPurpose
# Business     51298
# Home         51286
# Education    51005
# Other        50914
# Auto         50844
# Name: count, dtype: int64

# %%
df["Education"].value_counts().sort_values()
# Out:
# Education
# PhD            63537
# Master's       63541
# High School    63903
# Bachelor's     64366
# Name: count, dtype: int64

# %% [markdown]
# # 7. Null Value Analysis
#
# Null Value Analysis helps identify missing data in a dataset. Detecting and handling missing values is an important preprocessing step before performing data analysis or building machine learning models.
#
# ### Questions
#
# 1. Display the total number of missing values in each column of the dataset.
#
# 2. Display only the columns that contain one or more missing values.
#
# 3. Calculate the percentage of missing values for each column and sort the results in descending order.

# %%
df.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
missing_cols = df.columns[df.isnull().any()]
print(missing_cols)
# Out:
# Index([], dtype='object')

# %%
df.isnull().mean() * 100
# Out:
# LoanID            0.0
# Age               0.0
# Income            0.0
# LoanAmount        0.0
# CreditScore       0.0
# MonthsEmployed    0.0
# NumCreditLines    0.0
# InterestRate      0.0
# LoanTerm          0.0
# DTIRatio          0.0
# Education         0.0
# EmploymentType    0.0
# MaritalStatus     0.0
# HasMortgage       0.0
# HasDependents     0.0
# LoanPurpose       0.0
# HasCoSigner       0.0
# Default           0.0
# dtype: float64
